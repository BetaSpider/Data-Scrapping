# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb


data=pd.read_excel("E:\\github\\Data Scraping\\TOP 50 sci-fi movies IMDb.xlsx")
df=pd.DataFrame(data)
df
# Out:
#     S.no                                         Movie_name     Year  \
# 0      1                                          Inception     2010
# 1      2                                         The Matrix     1999
# 2      3                            The Empire Strikes Back     1980
# 3      4                  Everything Everywhere All at Once     2022
# 4      5                                       Interstellar     2014
# 5      6                         Terminator 2: Judgment Day     1991
# 6      7                                          Star Wars     1977
# 7      8                                 Back to the Future     1985
# 8      9                                              Alien     1979
# 9     10                  Spider-Man: Into the Spider-Verse     2018
# 10    11                                  Avengers: Endgame     2019
# 11    12                             Avengers: Infinity War     2018
# 12    13                                             WALL·E     2008
# ...

# %%
df.head()
# Out:
#    S.no                         Movie_name  Year Certificate     Time  \
# 0     1                          Inception  2010          UA  148 min
# 1     2                         The Matrix  1999           A  136 min
# 2     3            The Empire Strikes Back  1980          UA  124 min
# 3     4  Everything Everywhere All at Once  2022           R  139 min
# 4     5                       Interstellar  2014          UA  169 min
#
#                         Genre  Movie_rating      Director_name No of votes  \
# 0   Action, Adventure, Sci-Fi           8.8  Christopher Nolan   2,271,919
# 1              Action, Sci-Fi           8.7     Lana Wachowski   1,860,230
# 2  Action, Adventure, Fantasy           8.7     Irvin Kershner   1,251,988
# 3   Action, Adventure, Comedy           8.6           Dan Kwan      61,041
# 4    Adventure, Drama, Sci-Fi           8.6  Christopher Nolan   1,732,118
#
#   Gross amount
# 0     $292.58M
# 1     $171.48M
# 2     $290.48M
# 3       61,041
# ...

# %%
df.tail()
# Out:
#     S.no          Movie_name     Year Certificate     Time  \
# 45    46             Solaris     1972           U  167 min
# 46    47  Planet of the Apes     1968           U  112 min
# 47    48       Minnal Murali     2021      UA 16+  158 min
# 48    49      Thor: Ragnarok     2017          UA  130 min
# 49    50             Arrival  II 2016          UA  116 min
#
#                         Genre  Movie_rating          Director_name  \
# 45     Drama, Mystery, Sci-Fi           8.0       Andrei Tarkovsky
# 46          Adventure, Sci-Fi           8.0  Franklin J. Schaffner
# 47  Action, Adventure, Comedy           7.9           Basil Joseph
# 48  Action, Adventure, Comedy           7.9          Taika Waititi
# 49              Drama, Sci-Fi           7.9       Denis Villeneuve
#
#    No of votes Gross amount
# 45      89,764       89,764
# 46     177,597      $33.40M
# 47      27,414       27,414
# 48     700,108     $315.06M
# 49     670,326     $100.55M

# %%
df.columns
# Out:
# Index(['S.no', 'Movie_name', 'Year', 'Certificate', 'Time', 'Genre',
#        'Movie_rating', 'Director_name', 'No of votes', 'Gross amount'],
#       dtype='object')

# %%
df.set_index("S.no")
# Out:
#                                              Movie_name     Year Certificate  \
# S.no
# 1                                             Inception     2010          UA
# 2                                            The Matrix     1999           A
# 3                               The Empire Strikes Back     1980          UA
# 4                     Everything Everywhere All at Once     2022           R
# 5                                          Interstellar     2014          UA
# 6                            Terminator 2: Judgment Day     1991           A
# 7                                             Star Wars     1977          UA
# 8                                    Back to the Future     1985           U
# 9                                                 Alien     1979           R
# 10                    Spider-Man: Into the Spider-Verse     2018           U
# 11                                    Avengers: Endgame     2019          UA
# ...

# %%
sb.pairplot(data=df,palette="Set1")
